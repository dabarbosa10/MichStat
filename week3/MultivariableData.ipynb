# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_columns',100)

# %%
dataframe=pd.read_csv("nhanes_2015_2016.csv")

# %%
dataframe.head()
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  SDMVPSU  SDMVSTRA  \
# 0       1.0       5.0       1.0         2  134671.37        1       125
# 1       2.0       3.0       3.0         1   24328.56        1       125
# 2       1.0       3.0       1.0         2   12400.01        1       131
# 3       1.0       5.0       6.0         1  102718.00        1       131
# 4       1.0       4.0       3.0         5   17627.67        2       126
#
#    INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %%
col_names=dataframe.columns
col_names
# Out:
# Index(['SEQN', 'ALQ101', 'ALQ110', 'ALQ130', 'SMQ020', 'RIAGENDR', 'RIDAGEYR',
#        'RIDRETH1', 'DMDCITZN', 'DMDEDUC2', 'DMDMARTL', 'DMDHHSIZ', 'WTINT2YR',
#        'SDMVPSU', 'SDMVSTRA', 'INDFMPIR', 'BPXSY1', 'BPXDI1', 'BPXSY2',
#        'BPXDI2', 'BMXWT', 'BMXHT', 'BMXBMI', 'BMXLEG', 'BMXARML', 'BMXARMC',
#        'BMXWAIST', 'HIQ210'],
#       dtype='object')

# %%
keep=['BMXWT','BMXHT','BMXBMI','BMXLEG','BMXARML','BMXARMC','BMXWAIST']

# %%
df_BMX=dataframe[keep]

# %%
df_BMX.head()
# Out:
#    BMXWT  BMXHT  BMXBMI  BMXLEG  BMXARML  BMXARMC  BMXWAIST
# 0   94.8  184.5    27.8    43.3     43.6     35.9     101.1
# 1   90.4  171.4    30.8    38.0     40.0     33.2     107.9
# 2   83.4  170.1    28.8    35.6     37.0     31.0     116.5
# 3  109.8  160.9    42.4    38.5     37.7     38.3     110.1
# 4   55.2  164.9    20.3    37.4     36.0     27.2      80.4

# %%
[column for column in dataframe.columns if 'BP' in column]
# Out:
# ['BPXSY1', 'BPXDI1', 'BPXSY2', 'BPXDI2']

# %%
keep1=[column for column in dataframe.columns if 'BP' in column]

# %%
df_BPX=dataframe[keep1]
df_BPX
# Out:
#       BPXSY1  BPXDI1  BPXSY2  BPXDI2
# 0      128.0    70.0   124.0    64.0
# 1      146.0    88.0   140.0    88.0
# 2      138.0    46.0   132.0    44.0
# 3      132.0    72.0   134.0    68.0
# 4      100.0    70.0   114.0    54.0
# ...      ...     ...     ...     ...
# 5730   112.0    48.0   112.0    46.0
# 5731   118.0    68.0   116.0    76.0
# 5732   154.0    56.0   146.0    58.0
# 5733   104.0    62.0   106.0    66.0
# 5734   118.0    66.0   114.0    68.0
#
# [5735 rows x 4 columns]

# %%
dataframe.loc[:,keep].head(10)
# Out:
#    BMXWT  BMXHT  BMXBMI  BMXLEG  BMXARML  BMXARMC  BMXWAIST
# 0   94.8  184.5    27.8    43.3     43.6     35.9     101.1
# 1   90.4  171.4    30.8    38.0     40.0     33.2     107.9
# 2   83.4  170.1    28.8    35.6     37.0     31.0     116.5
# 3  109.8  160.9    42.4    38.5     37.7     38.3     110.1
# 4   55.2  164.9    20.3    37.4     36.0     27.2      80.4
# 5   64.4  150.0    28.6    34.4     33.5     31.4      92.9
# 6   76.6  165.4    28.0    38.8     38.0     34.0      86.6
# 7   64.5  151.3    28.2    34.1     33.1     31.5      93.3
# 8   72.4  166.1    26.2     NaN      NaN      NaN       NaN
# 9  108.3  179.4    33.6    46.0     44.1     38.5     116.0

# %%
#index locations
index_bool=np.isin(dataframe.columns,keep1)

# %%
index_bool
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False,  True,  True,
#         True,  True, False, False, False, False, False, False, False,
#        False])

# %%
dataframe.iloc[:,index_bool].head()
# Out:
#    BPXSY1  BPXDI1  BPXSY2  BPXDI2
# 0   128.0    70.0   124.0    64.0
# 1   146.0    88.0   140.0    88.0
# 2   138.0    46.0   132.0    44.0
# 3   132.0    72.0   134.0    68.0
# 4   100.0    70.0   114.0    54.0

# %%
#waist that are larger than the median
waist_median=pd.Series.median(dataframe['BMXWAIST']) #pd.Series.median is the function that calculates the median

# %%
waist_median
# Out:
# 98.3

# %%
#Now conditions
condition1= dataframe['BMXWAIST']>waist_median
print(condition1)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 5730    False
# 5731     True
# 5732    False
# 5733     True
# 5734    False
# Name: BMXWAIST, Length: 5735, dtype: bool

# %%
dataframe[condition1].head(3)
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
#
#    DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  SDMVPSU  SDMVSTRA  \
# 0       1.0       5.0       1.0         2  134671.37        1       125
# 1       2.0       3.0       3.0         1   24328.56        1       125
# 2       1.0       3.0       1.0         2   12400.01        1       131
#
#    INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 0      4.39   128.0    70.0   124.0    64.0   94.8  184.5    27.8    43.3
# 1      1.32   146.0    88.0   140.0    88.0   90.4  171.4    30.8    38.0
# 2      1.51   138.0    46.0   132.0    44.0   83.4  170.1    28.8    35.6
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# 0     43.6     35.9     101.1     2.0
# ...

# %%
#add another condition. 
condition2= dataframe['BMXLEG']<32
dataframe[condition1 & condition2].head(3)
# Out:
#      SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 15  83757     1.0     NaN     1.0       2         2        57         2
# 27  83785     2.0     1.0     1.0       1         2        60         2
# 39  83812     1.0     NaN     2.0       2         2        68         1
#
#     DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ  WTINT2YR  SDMVPSU  SDMVSTRA  \
# 15       1.0       1.0       4.0         5  11709.11        1       120
# 27       1.0       5.0       3.0         4  10495.87        1       128
# 39       1.0       3.0       1.0         3  10255.97        1       124
#
#     INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# 15      0.77   134.0    68.0   146.0    62.0   80.5  150.8    35.4    31.6
# 27      5.00   142.0    74.0   136.0    74.0   75.6  145.2    35.9    31.0
# 39      5.00   124.0    56.0   114.0    66.0   63.7  147.9    29.1    26.0
#
#     BMXARML  BMXARMC  BMXWAIST  HIQ210
# 15     32.7     33.7     113.5     2.0
# ...

# %%
df_small=dataframe.head(5)
df_small
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# 0  83732     1.0     NaN     1.0       1         1        62         3
# 1  83733     1.0     NaN     6.0       1         1        53         3
# 2  83734     1.0     NaN     NaN       1         1        78         3
# 3  83735     2.0     1.0     1.0       2         2        56         3
# 4  83736     2.0     1.0     1.0       2         2        42         4
#
#    DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ   WTINT2YR  SDMVPSU  SDMVSTRA  \
# 0       1.0       5.0       1.0         2  134671.37        1       125
# 1       2.0       3.0       3.0         1   24328.56        1       125
# 2       1.0       3.0       1.0         2   12400.01        1       131
# 3       1.0       5.0       6.0         1  102718.00        1       131
# 4       1.0       4.0       3.0         5   17627.67        2       126
#
#    INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# ...

# %%
df_small.index=['a','b','c','d','e'] #change the number index by letters
df_small.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
df_small.iloc[[1,2],:] #select all columns and rows 'a' and 'b'
# Out:
#     SEQN  ALQ101  ALQ110  ALQ130  SMQ020  RIAGENDR  RIDAGEYR  RIDRETH1  \
# b  83733     1.0     NaN     6.0       1         1        53         3
# c  83734     1.0     NaN     NaN       1         1        78         3
#
#    DMDCITZN  DMDEDUC2  DMDMARTL  DMDHHSIZ  WTINT2YR  SDMVPSU  SDMVSTRA  \
# b       2.0       3.0       3.0         1  24328.56        1       125
# c       1.0       3.0       1.0         2  12400.01        1       131
#
#    INDFMPIR  BPXSY1  BPXDI1  BPXSY2  BPXDI2  BMXWT  BMXHT  BMXBMI  BMXLEG  \
# b      1.32   146.0    88.0   140.0    88.0   90.4  171.4    30.8    38.0
# c      1.51   138.0    46.0   132.0    44.0   83.4  170.1    28.8    35.6
#
#    BMXARML  BMXARMC  BMXWAIST  HIQ210
# b     40.0     33.2     107.9     NaN
# c     37.0     31.0     116.5     2.0

# %%
df_small.loc[:,'BMXBMI']
# Out:
# a    27.8
# b    30.8
# c    28.8
# d    42.4
# e    20.3
# Name: BMXBMI, dtype: float64

# %%
df_small.loc[:,'BMXBMI'].values #gives a numpy array
# Out:
# array([27.8, 30.8, 28.8, 42.4, 20.3])

# %%
df_small['BMXBMI']
# Out:
# a    27.8
# b    30.8
# c    28.8
# d    42.4
# e    20.3
# Name: BMXBMI, dtype: float64
