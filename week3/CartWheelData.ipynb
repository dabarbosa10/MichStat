# %%
import numpy as np
import pandas as pd
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Cartwheeldata.csv")

# %%
pd.set_option('display.max_columns', 100)

# %%
#Look at the head of our DataFrame
data.head()
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
# 2   3   33      F            1       Y             1    66.0      64.0
# 3   4   39      F            1       N             0    64.0      63.0
# 4   5   27      M            2       N             0    73.0      75.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8
# 2          85        Y              1      7
# 3          87        Y              1     10
# 4          72        N              0      4

# %%
#Let's look at two variables we expected to hace a strong relationship: 'Height' and 'Wingspan'
plt.figure(figsize=(8,8))
sns.set(style="darkgrid")
sns.scatterplot(data["Height"],data["Wingspan"])

# %%
#Lets loog at two variables that we assume are not correlated:
plt.figure(figsize=(8,8))
sns.set(style="darkgrid")
sns.scatterplot(data["Wingspan"],data["CWDistance"])

# %%
#Let's look at two variables we expected to hace a strong relationship: 'Height' and 'Wingspan'
plt.figure(figsize=(8,8))
sns.set(style="darkgrid")
sns.scatterplot(data["Height"],data["Wingspan"],hue=data['Gender'])

# %%
#Lets loog at two variables that we assume are not correlated:
plt.figure(figsize=(8,8))
sns.set(style="darkgrid")
sns.scatterplot(data["Wingspan"],data["CWDistance"],hue=data['Gender'])

# %%
sns.boxplot(x=data["Wingspan"])

# %%
sns.boxplot(x=data["CWDistance"])

# %%
sns.set(style="whitegrid")
ax=sns.barplot(x=data["Glasses"],y=data["CWDistance"])

# %%
sns.set(style="whitegrid")
ax=sns.barplot(x=data["Glasses"],y=data["CWDistance"],hue=data['Gender'])
